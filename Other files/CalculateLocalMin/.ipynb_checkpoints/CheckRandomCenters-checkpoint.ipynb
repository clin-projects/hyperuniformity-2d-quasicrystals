# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

maxrad = 10
num_windows = 1000

x = np.sqrt(np.pi * float((maxrad/2)**2) / float(num_windows))
n = int(np.sqrt(num_windows))
a = np.linspace(-n * x,n *x,2*n+1)
grid = np.array([(i,j) for i in a for j in a])
dist = np.linalg.norm(grid,axis=1)
centers = grid[np.where(dist <= maxrad/2)[0]]

# %%
fig,ax=plt.subplots(figsize=(8,6))

#plt.scatter(centers[:,0], centers[:,1])
plt.scatter(centers2[:,0], centers2[:,1],color='red')
circle2 = plt.Circle((0, 0), maxrad/2, color='b', fill=False)
circle3 = plt.Circle((0, 0), maxrad, color='b', fill=False)

ax.add_artist(circle2)
ax.add_artist(circle3)

#plt.xlim(-10,10)
#plt.ylim(-10,10)

# %%
sample = np.random.rand(num_windows*2,2)*maxrad - np.array([maxrad/2,maxrad/2])
dist = np.linalg.norm(sample,axis=1)
centers2 = sample[np.where(dist<maxrad/2)][0:num_windows]

# %%
np.random.seed(2)

# %%
np.random.random()
# Out:
# 0.43599490214200376
