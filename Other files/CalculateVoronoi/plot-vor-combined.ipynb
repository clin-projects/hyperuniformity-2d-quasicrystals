# %%
import glob
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
from matplotlib.pyplot import cm 
from scipy.optimize import curve_fit

def f(x,a,b):
    return a*x + b

# %matplotlib inline

mpl.rc("savefig", dpi=100)

font = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 20}

# mpl.rcParams['text.usetex'] = True
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}'] #for \text command

mpl.rc('font', **font)

tau = (1+5**.5) / 2
rho = 2*(tau+1) / (tau+2) / (3-tau)**.5

# %%
v1 = np.load('vor1.npz')
v2 = np.load('vor2.npz')

# %%
fig, ax = plt.subplots(figsize=(8,6))

label1 = r'$\sigma_V / \mu_V$'
label2 = r'$\sigma_{V_2} / \mu_{V_2}$'

c1 = 'blue'
c2 = 'red'

ax.tick_params(axis='both',which='both',direction='out')


ln1 = ax.plot(v1['g'], v1['std']/v1['mn'],color=c1, markersize=8,marker='o', markeredgecolor='None',markerfacecolor=c1,lw=1, label=label1)

#plt.ylim(0.145,0.18)

#plt.ylabel(label1,fontsize=20)
plt.xlabel(r'$\gamma$',fontsize=25)


#ax2 = ax.twinx()
#ax2.tick_params(axis='both',which='both',direction='out')

ln2 = ax.plot(v2['g'], v2['std']/v2['mn'],color=c2, markersize=8, marker='^', markeredgecolor='None',markerfacecolor=c2,lw=1, label=label2)
#ax2.set_ylabel(label2,fontsize=20)


#lns = ln1+ln2
#labs = [l.get_label() for l in lns]
#ax.legend(lns, labs, loc=4, numpoints=1,frameon=False)

plt.annotate(label1, family='monospace',
                xy=(0.15,0.139),
                xycoords='data',
                xytext=(0,0), textcoords='offset points',
                horizontalalignment='center', verticalalignment='center',fontsize=25,
                bbox=dict(facecolor='white', edgecolor='None', alpha=1.0,pad=3.0)
                )

plt.annotate(label2, family='monospace',
                xy=(0.36,0.122),
                xycoords='data',
                xytext=(0,0), textcoords='offset points',
                horizontalalignment='center', verticalalignment='center',fontsize=25,
                bbox=dict(facecolor='white', edgecolor='None', alpha=1.0,pad=3.0)
                )


plt.tight_layout()

#fig.savefig('fig_lambda_global',dpi=600)

ax.set_yticks(np.arange(0.12,0.15,0.01),minor=True)

ax.set_xticks(np.arange(0,0.55,0.05),minor=True)

ax.set_ylim([0.095,0.15])
#ax2.set_ylim([0.095,0.15])
#ax2.set_yticks(np.arange(0.095,0.145,0.005),minor=True)

fig.savefig('fig_voronoi.pdf',dpi=600)
